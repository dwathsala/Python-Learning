# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Addition

# %% [markdown]
# ## Two numbers addition using python

# %%
print (2+3)
# Out:
# 5

# %% [markdown]
# ## Three numbers addition using python

# %%
print(3+8+4)
# Out:
# 15
